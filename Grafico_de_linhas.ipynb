# %% [markdown]
# <a href="https://colab.research.google.com/github/hlsvalle/curso_data_science/blob/master/Grafico_de_linhas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Gráfico de Linhas

# %%
#Importando as Bibliotecas Necessarias
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Obtenção dos Dados
data = "https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_03/dengue-dataset.csv"
df = pd.read_csv(data, index_col='data', parse_dates=True)

#Verificando as 5 primeiras Linhas do DataFrame
df.head()
# Out:
#             casos-confirmados  chuva  ...  temperatura-mininima  temperatura-maxima
# data                                  ...
# 1998-01-01                237  179.2  ...                  20.2                28.1
# 1998-02-01                331  226.3  ...                  20.0                28.0
# 1998-03-01                562  149.1  ...                  22.4                27.2
# 1998-04-01                187   46.4  ...                  18.1                26.0
# 1998-05-01                 32   88.3  ...                  15.7                22.9
#
# [5 rows x 5 columns]

# %%
df.isnull().sum().value_counts(ascending=False)
# Out:
# 0    4
# 8    1
# dtype: int64

# %%
df.describe()
# Out:
#        casos-confirmados       chuva  ...  temperatura-mininima  temperatura-maxima
# count         204.000000  196.000000  ...            204.000000          204.000000
# mean          357.539216  116.650000  ...             17.679412           25.565196
# std          1741.814759   96.631613  ...              3.336316            2.249864
# min             0.000000    0.800000  ...              8.200000           19.100000
# 25%             6.000000   43.850000  ...             15.075000           23.800000
# 50%            17.500000   86.650000  ...             18.150000           26.200000
# 75%            84.500000  177.925000  ...             20.400000           27.200000
# max         20428.000000  452.800000  ...             23.500000           30.100000
#
# [8 rows x 5 columns]

# %%
#Plotar os casos confirmados
fig, ax = plt.subplots()
df['casos-confirmados'].plot(kind='line', ax=ax)
ax.set_title("Dengue em Campinas")
ax.set_xlabel("Data")
ax.set_ylabel("Casos Confirmados")

plt.tight_layout();

# %%
#Selecionando Intervalo do DataFrame
fig, ax = plt.subplots()
df.loc['2007-01-01':'2014-12-01','temperatura-media'].plot(kind='line', ax=ax)
ax.set_title("Temperatura Média entre 2007 até 2014")
ax.set_xlabel("Data")
ax.set_ylabel("Temperatura Média")

plt.tight_layout()

# %%
#Plotar mais de um Gráfico Separadamente
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
df.loc['2007-01-01':'2014-12-01','temperatura-media'].plot(kind='line', ax=ax[0])
ax[0].set_title("Temperatura Média entre 2007 até 2014")
ax[0].set_xlabel("Data")
ax[0].set_ylabel("Temperatura Média")

df.loc['2007-01-01':'2014-12-01','casos-confirmados'].plot(kind='line', ax=ax[1])
ax[1].set_title("Casos Confirmados em Campinas")
ax[1].set_xlabel("Data")
ax[1].set_ylabel("Casos Confirmados")

plt.tight_layout();

# %%
#Plotar os graficos sobrepostos
df_norm = (df - df.mean()) / df.std() #Normalizando o Dataframe

#Plotar os graficos
fig, ax = plt.subplots(figsize=(8,4))

df_norm.loc['2007-01-01':'2014-12-01','temperatura-media'].plot(kind='line', ax=ax, color='green')
df_norm.loc['2007-01-01':'2014-12-01','casos-confirmados'].plot(kind='line', ax=ax)
df_norm.loc['2007-01-01':'2014-12-01','chuva'].plot(kind='line', ax = ax, color='red')

ax.set_title("Casos confirmados X Temperatura Média X Chuva")
ax.set_xlabel("Data")
ax.legend(loc='best')


plt.tight_layout()
